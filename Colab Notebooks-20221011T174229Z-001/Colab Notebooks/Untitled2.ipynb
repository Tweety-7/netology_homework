# %%
# ковычки у юзера_ид в purchase_log
# их нет во втором


'''
Переведите содержимое файла purchase_log.txt в словарь purchases вида:
{‘1840e0b9d4’: ‘Продукты’, ...}
'''

with open('purchase_log.txt', 'r') as f:
  file_purchase = f.readlines()
import json
dict_purchase = {}
# with open('purchase_log.txt', 'r') as f:
for line in file_purchase:
    line_d = json.loads(line)
    dict_purchase[line_d['user_id'].strip()] = line_d['category']
keys_purchace = dict_purchase.keys()
# print(keys_purchace)
# print(dict_purchase)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
'''
Для каждого user_id в файле visit_log.csv определите третий столбец с категорией покупки (если покупка была, сам файл visit_log.csv изменять не надо). Запишите в файлfunnel.csv визиты из файла visit_log.csv, 
в которых были покупки с указанием категории.
'''
# with open('visit_log.csv', 'r') as f_read:
#   with open('funnel.csv', 'w') as f_w:

# %%
j = 0
keys_purchace = dict_purchase.keys()
with open('visit_log.csv', 'r') as f:
  for line in f:
    print(line)
    id = line.strip().split(',')[0]
    id = "'" + id.strip() + "'"
    print(id)
    # print(str(id))
    if id in keys_purchace:
      print(id, dict_purchase[id])
      line_write = line + ',' + dict_purchase[id]
      print(line_write)
    j+=1
    if j> 5:
      break
# Out:
# user_id,source
#
# 'user_id'
# 6450655ae8,other
#
# '6450655ae8'
# b4ea53e670,other
#
# 'b4ea53e670'
# 0e37347152,other
#
# '0e37347152'
# 96064ae9e0,other
#
# '96064ae9e0'
# e1bd168161,context
#
# 'e1bd168161'
