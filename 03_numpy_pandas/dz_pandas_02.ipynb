# %%
"""
Задание 1
Скачайте с сайта grouplens.org...movielens/ 
датасет любого размера. Определите, 
какому фильму было выставлено больше всего оценок 5.0.
"""
import pandas as pd
db = pd.read_csv("ratings.csv")
# db.head()
db_5 = db[db.rating == 5.0]
db_5.head()
db_5.groupby('movieId').count().sort_values('rating',).tail(1)
"""
ВОПРОС ????
почему строчку выбирает с одним мувайди,
 но всегда считает ра зное кол-во ?? не понимаю =(
"""
# Out:
#          userId  rating  timestamp
# movieId
# 318        6042    6042       6042

# %%
"""
Задание 2
По данным файла power.csv 
посчитайте суммарное потребление
 стран Прибалтики 
 (Латвия, Литва и Эстония)
  категорий 4, 12 и 21 за период 
  с 2005 по 2010 года. 
  Не учитывайте в расчетах отрицательные значения quantity.
"""
data = pd.read_csv("power.csv")
# data.head()
# data_positive = data[(data.quantity >= 0)]
data_p = data[((data['country'] == 'Lithuania') | \
              (data['country'] == 'Latvia') |(data['country'] == 'Estonia'))]
data_q = data[((data['category'] == 4) | (data['category'] == 12) | (data['category'] == 21))]
data_q.head()
data_y = data[((data['year'] >= 2005) & (data['year'] <= 2010))]
data_work = data[((data.quantity >= 0)) & \
                 ((data['country'] == 'Lithuania') | \
              (data['country'] == 'Latvia') |(data['country'] == 'Estonia')) &\
              ((data['category'] == 4) | (data['category'] == 12) | (data['category'] == 21)) & \
              ((data['year'] >= 2005) & (data['year'] <= 2010)) \
                 ]
sum_quantity = data_work.quantity.sum()
print(f"суммарное потребление = {sum_quantity}")
# Out:
# суммарное потребление = 240580.0

# %%
"""
Задание 3
Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
Примеры страниц (необязательно брать именно эти)
"""
# тут просто сама вышла

pd.read_html('https://fortrader.org/quotes')[0]
# Out:
#                            Название   Цена  Изменение  Изменение(%)  Обновлено
# 0  EURRUB Курс евро к рублю сегодня  60.22        0.0           0.0        NaN
# 1       USDRUB Курс рубля к доллару  59.72        0.0           0.0        NaN

# %%
"""
вопрос 2 не получилось с сайта https://www.finanz.ru/valyuty/v-realnom-vremeni
ничего вытащить, хотя там и не одна таблица.
пыталась верхнюю, но что-то в атрибутах чтения поняла не так.
поможете справиться?
"""

# pd.read_html('www.finanz.ru...om-vremeni', attrs = {'class': 'headereiframe'})

# pd.read_html('www.finanz.ru...om-vremeni', attrs = {'class': 'header_user_pricebox'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-2df11bec3913> in <module>
#       3 """
#       4
# ----> 5 pd.read_html('www.finanz.ru...om-vremeni', attrs = {'class': 'headereiframe'})
#       6
#       7 # pd.read_html('www.finanz.ru...om-vremeni', attrs = {'class': 'header_user_pricebox'})
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111         na_values=na_values,
# ...
